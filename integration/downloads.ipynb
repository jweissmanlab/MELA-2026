# %%
# !wget https://zenodo.org/records/7244568/files/mouse_data.h5ad?download=1 -O /mnt/home/gokulg/data/qiu2022/qiu2022_combined.h5ad
# !wget https://zenodo.org/records/7244568/files/mouse_data.h5ad?download=1 -O /home/gokulg/orcd/scratch/lt/data/qiu2022_combined.h5ad
# Out:
# --2026-03-20 20:08:22--  https://zenodo.org/records/7244568/files/mouse_data.h5ad?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.52.235, 188.185.43.153, 137.138.153.219, ...
# Connecting to zenodo.org (zenodo.org)|137.138.52.235|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25643735352 (24G) [application/octet-stream]
# Saving to: ‘/home/gokulg/orcd/scratch/lt/data/qiu2022_combined.h5ad’
#
# /home/gokulg/orcd/s 100%[===================>]  23.88G  35.8MB/s    in 11m 29s
#
# 2026-03-20 20:19:52 (35.5 MB/s) - ‘/home/gokulg/orcd/scratch/lt/data/qiu2022_combined.h5ad’ saved [25643735352/25643735352]

# %%
# !wget https://shendure-web.gs.washington.edu/content/members/cxqiu/public/backup/jax/download/adata/adata_JAX_dataset_1.h5ad -O /mnt/home/gokulg/data/qiu2024/qiu2024_1.h5ad
# Out:
# --2026-03-19 11:19:05--  https://shendure-web.gs.washington.edu/content/members/cxqiu/public/backup/jax/download/adata/adata_JAX_dataset_1.h5ad
# Resolving shendure-web.gs.washington.edu (shendure-web.gs.washington.edu)... 128.208.8.136
# Connecting to shendure-web.gs.washington.edu (shendure-web.gs.washington.edu)|128.208.8.136|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11713901349 (11G)
# Saving to: ‘/mnt/home/gokulg/data/qiu2024/qiu2024_1.h5ad’
#
# /mnt/home/gokulg/da 100%[===================>]  10.91G  32.4MB/s    in 5m 30s
#
# 2026-03-19 11:24:36 (33.9 MB/s) - ‘/mnt/home/gokulg/data/qiu2024/qiu2024_1.h5ad’ saved [11713901349/11713901349]
