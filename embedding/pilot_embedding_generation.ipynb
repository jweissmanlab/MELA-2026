# %%
import scvi
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_h5ad("/home/gokulg/orcd/scratch/lt/data/embryos/combined_counts.h5ad")
hvgs = pd.read_csv("data/embryos/hvg_2000.txt", header=None)[0].tolist()
adata = adata[:, hvgs].copy()
