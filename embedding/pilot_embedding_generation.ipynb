# %%
import scvi
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_h5ad("../data/embryos/combined_counts.h5ad")
hvgs = pd.read_csv("../data/embryos/hvg_v5.csv", header=0)[0].tolist()
adata = adata[:, hvgs].copy()

# %%
model = scvi.model.SCVI.load("models/scvi_reprocessed/kl0.0_d50_l2/scvi_model", adata)
